# %%
using Plots

# %%
gr()
# Out:
# Plots.GRBackend()

# %%
f(x,p)=x^2 -p
# Out:
# f (generic function with 1 method)

# %%
df(x) =2x
# Out:
# df (generic function with 1 method)

# %%
p =2
# Out:
# 2

# %%
#初期値の設定
x_1 =2.0
# Out:
# 2.0

# %%
#近似列の値を保存する配列
x = [x_1]
# Out:
# 1-element Array{Float64,1}:
#  2.0

# %%
#計算を停止させたときのステップ数の宣言
N =1
# Out:
# 1

# %%
#ニュートン法による計算

for n in 1:100
    print(n,"  ",x[n],"  ",f(x[n],p),"\n")
    y = x[n] - f(x[n],p) / df(x[n])
    push!(x,y)    
    if abs(f(x[n],p)) < 1.0e-15
        N=n
        break
    end
end
# Out:
# 1  2.0  2.0
# 2  1.5  0.25
# 3  1.4166666666666667  0.006944444444444642
# 4  1.4142156862745099  6.007304882871267e-6
# 5  1.4142135623746899  4.510614104447086e-12
# 6  1.4142135623730951  4.440892098500626e-16

# %%
#誤差の計算
e=[abs(x[n]-sqrt(p)) for n in 1:N]
# Out:
# 6-element Array{Float64,1}:
#  0.5857864376269049
#  0.08578643762690485
#  0.002453104293571595
#  2.1239014147411694e-6
#  1.5947243525715749e-12
#  0.0

# %%
#誤差のプロット
plot(e,xlims=(1,N))
